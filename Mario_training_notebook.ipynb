# %% [markdown]
# # 1. Setup Mario

# %%
# !pip install gym_super_mario_bros==7.3.0 nes_py
# Out:
# Collecting gym_super_mario_bros==7.3.0
#   Using cached gym_super_mario_bros-7.3.0-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting nes_py
#   Using cached nes_py-8.2.1.tar.gz (77 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gym>=0.17.2 (from nes_py)
#   Using cached gym-0.26.2-py3-none-any.whl
# Requirement already satisfied: numpy>=1.18.5 in c:\users\cl502_12\.conda\envs\smbrl\lib\site-packages (from nes_py) (1.26.3)
# Collecting pyglet<=1.5.21,>=1.4.0 (from nes_py)
#   Using cached pyglet-1.5.21-py3-none-any.whl.metadata (7.6 kB)
# Collecting tqdm>=4.48.2 (from nes_py)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting cloudpickle>=1.2.0 (from gym>=0.17.2->nes_py)
#   Using cached cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting gym-notices>=0.0.4 (from gym>=0.17.2->nes_py)
#   Using cached gym_notices-0.0.8-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: colorama in c:\users\cl502_12\.conda\envs\smbrl\lib\site-packages (from tqdm>=4.48.2->nes_py) (0.4.6)
# Using cached gym_super_mario_bros-7.3.0-py2.py3-none-any.whl (198 kB)
# Using cached pyglet-1.5.21-py3-none-any.whl (1.1 MB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Building wheels for collected packages: nes_py
#   Building wheel for nes_py (setup.py): started
#   Building wheel for nes_py (setup.py): finished with status 'done'
#   Created wheel for nes_py: filename=nes_py-8.2.1-cp310-cp310-win_amd64.whl size=46134 sha256=e3b9f8fb952944e14cc7b79024e91d47122d73ee4f509d9f8a093a03ea96ec11
#   Stored in directory: c:\users\cl502_12\appdata\local\pip\cache\wheels\34\a7\d5\9aa14b15df740a53d41f702e4c795731b6c4da7925deb8476c
# Successfully built nes_py
# Installing collected packages: pyglet, gym-notices, tqdm, cloudpickle, gym, nes_py, gym_super_mario_bros
# Successfully installed cloudpickle-3.0.0 gym-0.26.2 gym-notices-0.0.8 gym_super_mario_bros-7.3.0 nes_py-8.2.1 pyglet-1.5.21 tqdm-4.66.4

# %%
# Import the game
import gym_super_mario_bros
# Import the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Import the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
# Setup game
env = gym_super_mario_bros.make('SuperMarioBros-v0',apply_api_compatibility=True,render_mode="human" )
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# Out:
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\gym\envs\registration.py:627: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'video.frames_per_second']
#   logger.warn(

# %%
# Create a flag - restart or not
done = True
# Loop through each frame in the game
for step in range(100000): 
    # Start the game to begin with 
    if done: 
        # Start the gamee
        env.reset()
    # Do random actions
    # state, reward, done, info = env.step(env.action_space.sample())
    state, reward, done, info, _ = env.step(env.action_space.sample())
    
    # Show the game on the screen
    env.render()
# Close the game
env.close()
# Out:
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\gym\utils\passive_env_checker.py:272: UserWarning: WARN: No render modes was declared in the environment (env.metadata['render_modes'] is None or not defined), you may have trouble when calling `.render()`.
#   logger.warn(
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in scalar subtract
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 14
#      11     state, reward, done, info, _ = env.step(env.action_space.sample())
#      13     # Show the game on the screen
# ---> 14     env.render()
#      15 # Close the game
#      16 env.close()
#
# File ~\.conda\envs\smbrl\lib\site-packages\gym\core.py:329, in Wrapper.render(self, *args, **kwargs)
#     325 def render(
#     326     self, *args, **kwargs
#     327 ) -> Optional[Union[RenderFrame, List[RenderFrame]]]:
#     328     """Renders the environment."""
# --> 329     return self.env.render(*args, **kwargs)
#
# File ~\.conda\envs\smbrl\lib\site-packages\gym\core.py:329, in Wrapper.render(self, *args, **kwargs)
#     325 def render(
#     326     self, *args, **kwargs
#     327 ) -> Optional[Union[RenderFrame, List[RenderFrame]]]:
#     328     """Renders the environment."""
# --> 329     return self.env.render(*args, **kwargs)
#
# File ~\.conda\envs\smbrl\lib\site-packages\gym\wrappers\order_enforcing.py:51, in OrderEnforcing.render(self, *args, **kwargs)
#      46 if not self._disable_render_order_enforcing and not self._has_reset:
#      47     raise ResetNeeded(
#      48         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      49         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50     )
# ---> 51 return self.env.render(*args, **kwargs)
#
# File ~\.conda\envs\smbrl\lib\site-packages\gym\wrappers\env_checker.py:55, in PassiveEnvChecker.render(self, *args, **kwargs)
#      53     return env_render_passive_checker(self.env, *args, **kwargs)
#      54 else:
# ---> 55     return self.env.render(*args, **kwargs)
#
# File ~\.conda\envs\smbrl\lib\site-packages\gym\wrappers\compatibility.py:118, in EnvCompatibility.render(self)
#     112 def render(self) -> Any:
#     113     """Renders the environment.
#     114
#     115     Returns:
#     116         The rendering of the environment, depending on the render mode
#     117     """
# --> 118     return self.env.render(mode=self.render_mode)
#
# File ~\.conda\envs\smbrl\lib\site-packages\nes_py\nes_env.py:386, in NESEnv.render(self, mode)
#     380         self.viewer = ImageViewer(
#     381             caption=caption,
#     382             height=SCREEN_HEIGHT,
#     383             width=SCREEN_WIDTH,
#     384         )
#     385     # show the screen on the image viewer
# --> 386     self.viewer.show(self.screen)
#     387 elif mode == 'rgb_array':
#     388     return self.screen
#
# File ~\.conda\envs\smbrl\lib\site-packages\nes_py\_image_viewer.py:149, in ImageViewer.show(self, frame)
#     147 # send the image to the window
#     148 image.blit(0, 0, width=self._window.width, height=self._window.height)
# --> 149 self._window.flip()
#
# File ~\.conda\envs\smbrl\lib\site-packages\pyglet\window\win32\__init__.py:380, in Win32Window.flip(self)
#     377 if self.style in ('overlay', 'transparent'):
#     378     self.update_transparency()
# --> 380 self.context.flip()
#
# File ~\.conda\envs\smbrl\lib\site-packages\pyglet\gl\win32.py:252, in Win32Context.flip(self)
#     251 def flip(self):
# --> 252     _gdi32.SwapBuffers(self.canvas.hdc)
#
# KeyboardInterrupt:

# %%
env.close()

# %% [markdown]
# # 2. Preprocess Environment

# %%
# Install stable baselines for RL stuff
# !pip install stable-baselines3[extra]
# Out:
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3[extra])
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\cl502_12\.conda\envs\smbrl\lib\site-packages (from stable-baselines3[extra]) (1.26.3)
# Requirement already satisfied: torch>=1.13 in c:\users\cl502_12\.conda\envs\smbrl\lib\site-packages (from stable-baselines3[extra]) (2.3.0+cu121)
# Requirement already satisfied: cloudpickle in c:\users\cl502_12\.conda\envs\smbrl\lib\site-packages (from stable-baselines3[extra]) (3.0.0)
# Collecting pandas (from stable-baselines3[extra])
#   Downloading pandas-2.2.2-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib (from stable-baselines3[extra])
#   Downloading matplotlib-3.8.4-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting opencv-python (from stable-baselines3[extra])
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting pygame (from stable-baselines3[extra])
#   Downloading pygame-2.5.2-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting tensorboard>=2.9.1 (from stable-baselines3[extra])
#   Using cached tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: psutil in c:\users\cl502_12\.conda\envs\smbrl\lib\site-packages (from stable-baselines3[extra]) (5.9.8)
# Requirement already satisfied: tqdm in c:\users\cl502_12\.conda\envs\smbrl\lib\site-packages (from stable-baselines3[extra]) (4.66.4)
# Collecting rich (from stable-baselines3[extra])
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting shimmy~=1.3.0 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Downloading Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in c:\users\cl502_12\.conda\envs\smbrl\lib\site-packages (from stable-baselines3[extra]) (10.2.0)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting click (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: requests in c:\users\cl502_12\.conda\envs\smbrl\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.31.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ---------------------------------------- 0.0/434.7 kB ? eta -:--:--
#       --------------------------------------- 10.2/434.7 kB ? eta -:--:--
#      -- ---------------------------------- 30.7/434.7 kB 325.1 kB/s eta 0:00:02
#      -- ---------------------------------- 30.7/434.7 kB 325.1 kB/s eta 0:00:02
#      --- --------------------------------- 41.0/434.7 kB 245.8 kB/s eta 0:00:02
#      ----- ------------------------------- 61.4/434.7 kB 297.7 kB/s eta 0:00:02
#      ------ ------------------------------ 71.7/434.7 kB 245.8 kB/s eta 0:00:02
#      ------ ------------------------------ 71.7
kB/s eta 0:00:01
#    -------------------- ----------------- 122.9/227.3 kB 133.5 kB/s eta 0:00:01
#    ----------------------- -------------- 143.4/227.3 kB 139.7 kB/s eta 0:00:01
#    ----------------------- -------------- 143.4/227.3 kB 139.7 kB/s eta 0:00:01
#    --------------------------- ---------- 163.8/227.3 kB 148.8 kB/s eta 0:00:01
#    ----------------------------- -------- 174.1/227.3 kB 147.6 kB/s eta 0:00:01
#    ----------------------------- -------- 174.1/227.3 kB 147.6 kB/s eta 0:00:01
#    -------------------------------- ----- 194.6/227.3 kB 153.2 kB/s eta 0:00:01
#    -------------------------------- ----- 194.6/227.3 kB 153.2 kB/s eta 0:00:01
#    ---------------------------------- --- 204.8/227.3 kB 153.7 kB/s eta 0:00:01
#    -------------------------------------  225.3/227.3 kB 161.9 kB/s eta 0:00:01
#    -------------------------------------- 227.3/227.3 kB 157.8 kB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml): started
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml): finished with status 'done'
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446678 sha256=5c78c7cdbc374426b4a55746cfd1f3d76a687764dc06f3bdc46bf9bd6e8fff78
#   Stored in directory: c:\users\cl502_12\appdata\local\pip\cache\wheels\6b\1b\ef\a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: pytz, farama-notifications, werkzeug, tzdata, tensorboard-data-server, pyparsing, pygame, protobuf, opencv-python, mdurl, markdown, kiwisolver, importlib-resources, gymnasium, grpcio, fonttools, cycler, contourpy, click, absl-py, tensorboard, shimmy, pandas, matplotlib, markdown-it-py, AutoROM.accept-rom-license, autorom, ale-py, stable-baselines3, rich
# Successfully installed AutoROM.accept-rom-license-0.6.1 absl-py-2.1.0 ale-py-0.8.1 autorom-0.6.1 click-8.1.7 contourpy-1.2.1 cycler-0.12.1 farama-notifications-0.0.4 fonttools-4.51.0 grpcio-1.63.0 gymnasium-0.29.1 importlib-resources-6.4.0 kiwisolver-1.4.5 markdown-3.6 markdown-it-py-3.0.0 matplotlib-3.8.4 mdurl-0.1.2 opencv-python-4.9.0.80 pandas-2.2.2 protobuf-5.26.1 pygame-2.5.2 pyparsing-3.1.2 pytz-2024.1 rich-13.7.1 shimmy-1.3.0 stable-baselines3-2.3.2 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tzdata-2024.1 werkzeug-3.0.3

# %%
# Import Frame Stacker Wrapper and GrayScaling Wrapper
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
# Import Matplotlib to show the impact of frame stacking
from matplotlib import pyplot as plt

# %%
# 1. Create the base environment
JoypadSpace.reset = lambda self, **kwargs: self.env.reset(**kwargs)
# env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = gym_super_mario_bros.make('SuperMarioBros-v0', apply_api_compatibility=True, render_mode='human')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')
# Out:
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\gym\envs\registration.py:627: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'video.frames_per_second']
#   logger.warn(
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
state = env.reset()

# %%
state, reward, done, info = env.step([5])
# Out:
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %%
plt.figure(figsize=(20,16))
for idx in range(state.shape[3]):
    plt.subplot(1,4,idx+1)
    plt.imshow(state[0][:,:,idx])
plt.show()

# %% [markdown]
# # 3. Train the RL Model

# %%
# Import os for file path management
import os 
# Import PPO for algos
from stable_baselines3 import PPO
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
# This is the AI model started
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, n_steps=512)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
# Train the AI model, this is where the AI model starts to learn
# model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/PPO_1
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in scalar subtract
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ----------------------------
# | time/              |     |
# |    fps             | 43  |
# |    iterations      | 1   |
# |    time_elapsed    | 11  |
# |    total_timesteps | 512 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 2             |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 1.4275545e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.000825      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 158           |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000239     |
# |    value_loss           | 484           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 3             |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 4.3214182e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00546       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.069         |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000672     |
# |    value_loss           | 1.18          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 43           |
# |    iterations           | 4            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 8.570845e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.0266      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0778       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000117    |
# |    value_loss           | 0.524        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 43            |
# |    iterations           | 5             |
# |    time_elapsed         | 59            |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 2.9371586e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00252      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.364         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | 2.61e-05      |
# |    value_loss           | 0.809         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 6             |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 6.2282197e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00395       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.198         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000111     |
# |    value_loss           | 0.538         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 7             |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 3.3142278e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00114      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.255         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -3.91e-05     |
# |    value_loss           | 0.563         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 8            |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 9.310199e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00747     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0914       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000142    |
# |    value_loss           | 0.24         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 9             |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 1.0750489e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00729       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.305         |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000236     |
# |    value_loss           | 0.525         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 10            |
# |    time_elapsed         | 120           |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 5.3661643e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00407       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0708        |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -8.57e-05     |
# |    value_loss           | 0.2           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 11           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 6.055925e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00261      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0549       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -9.1e-05     |
# |    value_loss           | 0.151        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 43            |
# |    iterations           | 12            |
# |    time_elapsed         | 141           |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.7142156e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -5.48e-06     |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0851        |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000354     |
# |    value_loss           | 0.169         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 43            |
# |    iterations           | 13            |
# |    time_elapsed         | 153           |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 2.4099601e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0061        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0653        |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000395     |
# |    value_loss           | 0.143         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 43            |
# |    iterations           | 14            |
# |    time_elapsed         | 164           |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 1.8024584e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0032        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 34.1          |
# |    n_updates            | 130           |
# |    policy_gradient_loss | 0.000198      |
# |    value_loss           | 78.8          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 43            |
# |    iterations           | 15            |
# |    time_elapsed         | 175           |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 1.4188816e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0128        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.14          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000243     |
# |    value_loss           | 0.363         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 16            |
# |    time_elapsed         | 186           |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 7.5175194e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0184        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0785        |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000137     |
# |    value_loss           | 0.262         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 17            |
# |    time_elapsed         | 196           |
# |    total_timesteps      | 8704          |
# | train/                  |               |
# |    approx_kl            | 4.6260888e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00521       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 94.9          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000101     |
# |    value_loss           | 249           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 44           |
# |    iterations           | 18           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 8.070504e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0259       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 92           |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.000281     |
# |    value_loss           | 171          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 19            |
# |    time_elapsed         | 218           |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 4.5344466e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0102        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.254         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000408     |
# |    value_loss           | 1.95          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 20            |
# |    time_elapsed         | 230           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 1.0360265e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.000898      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0745        |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 3.51e-05      |
# |    value_loss           | 1.24          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 21            |
# |    time_elapsed         | 241           |
# |    total_timesteps      | 10752         |
# | train/                  |               |
# |    approx_kl            | 3.5004923e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0479        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.294         |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 0.000103      |
# |    value_loss           | 0.927         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 22            |
# |    time_elapsed         | 252           |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 1.5444588e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.037         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.1           |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000178     |
# |    value_loss           | 0.63          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 23            |
# |    time_elapsed         | 263           |
# |    total_timesteps      | 11776         |
# | train/                  |               |
# |    approx_kl            | 1.0442454e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00436       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.133         |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000101     |
# |    value_loss           | 0.502         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 24            |
# |    time_elapsed         | 273           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 1.5595811e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0125        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.205         |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.00021      |
# |    value_loss           | 0.479         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 25            |
# |    time_elapsed         | 284           |
# |    total_timesteps      | 12800         |
# | train/                  |               |
# |    approx_kl            | 1.9526575e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.011         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.121         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000337     |
# |    value_loss           | 0.457         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 45           |
# |    iterations           | 26           |
# |    time_elapsed         | 295          |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 9.661773e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0077      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0761       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000141    |
# |    value_loss           | 0.295        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 27            |
# |    time_elapsed         | 306           |
# |    total_timesteps      | 13824         |
# | train/                  |               |
# |    approx_kl            | 2.2348017e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00589       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.157         |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000288     |
# |    value_loss           | 0.428         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 28            |
# |    time_elapsed         | 317           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 1.8898863e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00746       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.11          |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000272     |
# |    value_loss           | 0.221         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 29            |
# |    time_elapsed         | 327           |
# |    total_timesteps      | 14848         |
# | train/                  |               |
# |    approx_kl            | 2.8596842e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0257       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.27          |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000451     |
# |    value_loss           | 0.419         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 45           |
# |    iterations           | 30           |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 5.682197e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00484     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.268        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000765    |
# |    value_loss           | 0.374        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 45           |
# |    iterations           | 31           |
# |    time_elapsed         | 349          |
# |    total_timesteps      | 15872        |
# | train/                  |              |
# |    approx_kl            | 2.029934e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0711       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.76         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 2.84e-05     |
# |    value_loss           | 13.3         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 32            |
# |    time_elapsed         | 360           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 4.6180794e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0397        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 11.6          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000165     |
# |    value_loss           | 40.8          |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 45             |
# |    iterations           | 33             |
# |    time_elapsed         | 370            |
# |    total_timesteps      | 16896          |
# | train/                  |                |
# |    approx_kl            | 0.000100073055 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.94          |
# |    explained_variance   | 0.0453         |
# |    learning_rate        | 1e-06          |
# |    loss                 | 159            |
# |    n_updates            | 320            |
# |    policy_gradient_loss | 0.000413       |
# |    value_loss           | 382            |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 34            |
# |    time_elapsed         | 381           |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 0.00017756119 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0506        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 113           |
# |    n_updates            | 330           |
# |    policy_gradient_loss | 0.000416      |
# |    value_loss           | 223           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 45           |
# |    iterations           | 35           |
# |    time_elapsed         | 392          |
# |    total_timesteps      | 17920        |
# | train/                  |              |
# |    approx_kl            | 5.970674e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.193       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0992       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000114    |
# |    value_loss           | 2.9          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 36            |
# |    time_elapsed         | 403           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 1.5653903e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0753        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.154         |
# |    n_updates            | 350           |
# |    policy_gradient_loss | 7.15e-05      |
# |    value_loss           | 1.76          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 37            |
# |    time_elapsed         | 414           |
# |    total_timesteps      | 18944         |
# | train/                  |               |
# |    approx_kl            | 1.1474476e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.19          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.138         |
# |    n_updates            | 360           |
# |    policy_gradient_loss | 9.48e-05      |
# |    value_loss           | 1.04          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 38            |
# |    time_elapsed         | 425           |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 1.7850543e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0832        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.145         |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000133     |
# |    value_loss           | 0.801         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 39            |
# |    time_elapsed         | 435           |
# |    total_timesteps      | 19968         |
# | train/                  |               |
# |    approx_kl            | 2.4370267e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0141        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.104         |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000152     |
# |    value_loss           | 0.525         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 40            |
# |    time_elapsed         | 447           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 4.4715125e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.246         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.309         |
# |    n_updates            | 390           |
# |    policy_gradient_loss | 0.000124      |
# |    value_loss           | 0.789         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 45           |
# |    iterations           | 41           |
# |    time_elapsed         | 458          |
# |    total_timesteps      | 20992        |
# | train/                  |              |
# |    approx_kl            | 3.285706e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0144      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0715       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000271    |
# |    value_loss           | 0.254        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 42            |
# |    time_elapsed         | 469           |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 2.9667513e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0149        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0618        |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000223     |
# |    value_loss           | 0.213         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 43            |
# |    time_elapsed         | 480           |
# |    total_timesteps      | 22016         |
# | train/                  |               |
# |    approx_kl            | 1.4746562e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00825       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0749        |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.00011      |
# |    value_loss           | 0.176         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 44            |
# |    time_elapsed         | 490           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.2409291e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0134       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.08          |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000165     |
# |    value_loss           | 0.216         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 45            |
# |    iterations           | 45            |
# |    time_elapsed         | 501           |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 3.7130434e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.000553      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0936        |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000374     |
# |    value_loss           | 0.212         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 46            |
# |    time_elapsed         | 511           |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 4.2995205e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0117       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0712        |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000445     |
# |    value_loss           | 0.176         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 47            |
# |    time_elapsed         | 522           |
# |    total_timesteps      | 24064         |
# | train/                  |               |
# |    approx_kl            | 3.7676306e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0216        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0643        |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000443     |
# |    value_loss           | 0.239         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 48            |
# |    time_elapsed         | 533           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 2.1283864e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0233        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0565        |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.00024      |
# |    value_loss           | 0.152         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 49            |
# |    time_elapsed         | 543           |
# |    total_timesteps      | 25088         |
# | train/                  |               |
# |    approx_kl            | 0.00018580642 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0859        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 188           |
# |    n_updates            | 480           |
# |    policy_gradient_loss | 0.000113      |
# |    value_loss           | 443           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 50           |
# |    time_elapsed         | 554          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 5.204929e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | -0.119       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.147        |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.000183     |
# |    value_loss           | 1.07         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 51           |
# |    time_elapsed         | 565          |
# |    total_timesteps      | 26112        |
# | train/                  |              |
# |    approx_kl            | 1.231255e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0426       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.237        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -2.4e-05     |
# |    value_loss           | 0.562        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 52            |
# |    time_elapsed         | 575           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.3780082e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0196       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.19          |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -7.36e-05     |
# |    value_loss           | 0.446         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 53            |
# |    time_elapsed         | 586           |
# |    total_timesteps      | 27136         |
# | train/                  |               |
# |    approx_kl            | 2.4177018e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.00285      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.147         |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.000254     |
# |    value_loss           | 0.446         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 54            |
# |    time_elapsed         | 596           |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 1.9356376e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.02         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.132         |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.000211     |
# |    value_loss           | 0.357         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 55            |
# |    time_elapsed         | 607           |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 3.1552045e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.00765       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.139         |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.000351     |
# |    value_loss           | 0.283         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 56            |
# |    time_elapsed         | 617           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 5.0664996e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0403        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.123         |
# |    n_updates            | 550           |
# |    policy_gradient_loss | -0.000499     |
# |    value_loss           | 0.26          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 57            |
# |    time_elapsed         | 627           |
# |    total_timesteps      | 29184         |
# | train/                  |               |
# |    approx_kl            | 1.9155908e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.139         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.164         |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -0.000238     |
# |    value_loss           | 0.295         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 58            |
# |    time_elapsed         | 638           |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 4.0037092e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0102        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.106         |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.000495     |
# |    value_loss           | 0.26          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 59            |
# |    time_elapsed         | 649           |
# |    total_timesteps      | 30208         |
# | train/                  |               |
# |    approx_kl            | 1.9624247e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0136       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0962        |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -0.000186     |
# |    value_loss           | 0.207         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 60            |
# |    time_elapsed         | 660           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 3.6844052e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0178       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0588        |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -0.000375     |
# |    value_loss           | 0.124         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 61           |
# |    time_elapsed         | 670          |
# |    total_timesteps      | 31232        |
# | train/                  |              |
# |    approx_kl            | 6.196031e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | -0.00214     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.078        |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.000635    |
# |    value_loss           | 0.153        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 62           |
# |    time_elapsed         | 680          |
# ...
# |    entropy_loss         | -0.836        |
# |    explained_variance   | -0.151        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0958        |
# |    n_updates            | 19330         |
# |    policy_gradient_loss | -3.45e-05     |
# |    value_loss           | 0.175         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 1935          |
# |    time_elapsed         | 21294         |
# |    total_timesteps      | 990720        |
# | train/                  |               |
# |    approx_kl            | 0.00027671224 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.809        |
# |    explained_variance   | 0.705         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 49.1          |
# |    n_updates            | 19340         |
# |    policy_gradient_loss | -0.00164      |
# |    value_loss           | 137           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1936         |
# |    time_elapsed         | 21305        |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0014351066 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 108          |
# |    n_updates            | 19350        |
# |    policy_gradient_loss | 0.000695     |
# |    value_loss           | 276          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1937         |
# |    time_elapsed         | 21316        |
# |    total_timesteps      | 991744       |
# | train/                  |              |
# |    approx_kl            | 0.0003614854 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 332          |
# |    n_updates            | 19360        |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 485          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 1938          |
# |    time_elapsed         | 21327         |
# |    total_timesteps      | 992256        |
# | train/                  |               |
# |    approx_kl            | 0.00082087156 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.761        |
# |    explained_variance   | -0.484        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.308         |
# |    n_updates            | 19370         |
# |    policy_gradient_loss | -0.000441     |
# |    value_loss           | 2.85          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1939         |
# |    time_elapsed         | 21338        |
# |    total_timesteps      | 992768       |
# | train/                  |              |
# |    approx_kl            | 0.0003601549 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.786       |
# |    explained_variance   | 0.775        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 50           |
# |    n_updates            | 19380        |
# |    policy_gradient_loss | 0.000128     |
# |    value_loss           | 97.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1940         |
# |    time_elapsed         | 21349        |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0002085088 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.863       |
# |    explained_variance   | -0.635       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0928       |
# |    n_updates            | 19390        |
# |    policy_gradient_loss | -0.000509    |
# |    value_loss           | 0.303        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 1941          |
# |    time_elapsed         | 21360         |
# |    total_timesteps      | 993792        |
# | train/                  |               |
# |    approx_kl            | 0.00045301602 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.878        |
# |    explained_variance   | -0.881        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0795        |
# |    n_updates            | 19400         |
# |    policy_gradient_loss | -0.00109      |
# |    value_loss           | 0.24          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1942         |
# |    time_elapsed         | 21371        |
# |    total_timesteps      | 994304       |
# | train/                  |              |
# |    approx_kl            | 0.0012107958 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | -1.16        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.098        |
# |    n_updates            | 19410        |
# |    policy_gradient_loss | -0.000644    |
# |    value_loss           | 0.24         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1943         |
# |    time_elapsed         | 21382        |
# |    total_timesteps      | 994816       |
# | train/                  |              |
# |    approx_kl            | 0.0026615243 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.93        |
# |    explained_variance   | -0.465       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0813       |
# |    n_updates            | 19420        |
# |    policy_gradient_loss | -0.00421     |
# |    value_loss           | 0.199        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1944         |
# |    time_elapsed         | 21393        |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0022513168 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.905       |
# |    explained_variance   | -0.382       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0793       |
# |    n_updates            | 19430        |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 0.199        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 1945          |
# |    time_elapsed         | 21405         |
# |    total_timesteps      | 995840        |
# | train/                  |               |
# |    approx_kl            | 0.00078657223 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.882        |
# |    explained_variance   | -0.447        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.18          |
# |    n_updates            | 19440         |
# |    policy_gradient_loss | -0.00114      |
# |    value_loss           | 0.264         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1946         |
# |    time_elapsed         | 21416        |
# |    total_timesteps      | 996352       |
# | train/                  |              |
# |    approx_kl            | 5.477434e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.892       |
# |    explained_variance   | -0.732       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.112        |
# |    n_updates            | 19450        |
# |    policy_gradient_loss | -7.88e-06    |
# |    value_loss           | 0.232        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1947         |
# |    time_elapsed         | 21427        |
# |    total_timesteps      | 996864       |
# | train/                  |              |
# |    approx_kl            | 0.0067638867 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.926       |
# |    explained_variance   | -0.514       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.087        |
# |    n_updates            | 19460        |
# |    policy_gradient_loss | -0.0044      |
# |    value_loss           | 0.162        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1948         |
# |    time_elapsed         | 21438        |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0001875097 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | -0.641       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.076        |
# |    n_updates            | 19470        |
# |    policy_gradient_loss | -0.000324    |
# |    value_loss           | 0.233        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1949         |
# |    time_elapsed         | 21448        |
# |    total_timesteps      | 997888       |
# | train/                  |              |
# |    approx_kl            | 0.0003963278 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.952       |
# |    explained_variance   | -1.21        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.16         |
# |    n_updates            | 19480        |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 0.381        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 1950          |
# |    time_elapsed         | 21459         |
# |    total_timesteps      | 998400        |
# | train/                  |               |
# |    approx_kl            | 0.00028901396 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.948        |
# |    explained_variance   | -0.375        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0807        |
# |    n_updates            | 19490         |
# |    policy_gradient_loss | -0.000589     |
# |    value_loss           | 0.175         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1951         |
# |    time_elapsed         | 21469        |
# |    total_timesteps      | 998912       |
# | train/                  |              |
# |    approx_kl            | 0.0016941084 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.731       |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 70.9         |
# |    n_updates            | 19500        |
# |    policy_gradient_loss | -0.00436     |
# |    value_loss           | 224          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 1952          |
# |    time_elapsed         | 21480         |
# |    total_timesteps      | 999424        |
# | train/                  |               |
# |    approx_kl            | 0.00026921625 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.818        |
# |    explained_variance   | 0.945         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 27            |
# |    n_updates            | 19510         |
# |    policy_gradient_loss | 0.000155      |
# |    value_loss           | 51.6          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 1953         |
# |    time_elapsed         | 21491        |
# |    total_timesteps      | 999936       |
# | train/                  |              |
# |    approx_kl            | 0.0004961104 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.909       |
# |    explained_variance   | -0.17        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.187        |
# |    n_updates            | 19520        |
# |    policy_gradient_loss | -0.000469    |
# |    value_loss           | 0.466        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 1954          |
# |    time_elapsed         | 21502         |
# |    total_timesteps      | 1000448       |
# | train/                  |               |
# |    approx_kl            | 0.00010716205 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.92         |
# |    explained_variance   | -0.115        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.207         |
# |    n_updates            | 19530         |
# |    policy_gradient_loss | 6.31e-05      |
# |    value_loss           | 0.469         |
# -------------------------------------------

# %%
# model.save('thisisatestmodel')

# %% [markdown]
# # 4. Test it Out

# %%
# Load model
model = PPO.load('./train/best_model_1000000')

# %%
state = env.reset()

# %%
# Start the game 
state = env.reset()
# Loop through the game
while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\gym\utils\passive_env_checker.py:272: UserWarning: WARN: No render modes was declared in the environment (env.metadata['render_modes'] is None or not defined), you may have trouble when calling `.render()`.
#   logger.warn(
# C:\Users\cl502_12\.conda\envs\smbrl\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in scalar subtract
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 7
#       4 while True:
#       6     action, _ = model.predict(state)
# ----> 7     state, reward, done, info = env.step(action)
#       8     env.render()
#
# File ~\.conda\envs\smbrl\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~\.conda\envs\smbrl\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py:38, in VecFrameStack.step_wait(self)
#      30 def step_wait(
#      31     self,
#      32 ) -> Tuple[
#    (...)
#      36     List[Dict[str, Any]],
#      37 ]:
# ---> 38     observations, rewards, dones, infos = self.venv.step_wait()
#      39     observations, infos = self.stacked_obs.update(observations, dones, infos)  # type: ignore[arg-type]
#      40     return observations, rewards, dones, infos
#
# File ~\.conda\envs\smbrl\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~\.conda\envs\smbrl\lib\site-packages\shimmy\openai_gym_compatibility.py:117, in GymV26CompatibilityV0.step(self, action)
#     108 def step(self, action: ActType) -> tuple[ObsType, float, bool, bool, dict]:
#     109     """Steps through the environment.
#     110
#     111     Args:
#    (...)
#     115         (observation, reward, terminated, truncated, info)
#     116     """
# --> 117     return self.gym_env.step(action)
#
# File ~\.conda\envs\smbrl\lib\site-packages\gym\core.py:384, in ObservationWrapper.step(self, action)
#     382 def step(self, action):
#     383     """Returns a modified observation using :meth:`self.observation` after calling :meth:`env.step`."""
# --> 384     observation, reward, terminated, truncated, info = self.env.step(action)
#     385     return self.observation(observation), reward, terminated, truncated, info
#
# File ~\.conda\envs\smbrl\lib\site-packages\nes_py\wrappers\joypad_space.py:74, in JoypadSpace.step(self, action)
#      59 """
#      60 Take a step using the given action.
#      61
#    (...)
#      71
#      72 """
#      73 # take the step and record the output
# ---> 74 return self.env.step(self._action_map[action])
#
# File ~\.conda\envs\smbrl\lib\site-packages\gym\wrappers\time_limit.py:50, in TimeLimit.step(self, action)
#      39 def step(self, action):
#      40     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      41
#      42     Args:
#    (...)
#      48
#      49     """
# ---> 50     observation, reward, terminated, truncated, info = self.env.step(action)
#      51     self._elapsed_steps += 1
#      53     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~\.conda\envs\smbrl\lib\site-packages\gym\wrappers\order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File ~\.conda\envs\smbrl\lib\site-packages\gym\wrappers\env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File ~\.conda\envs\smbrl\lib\site-packages\gym\wrappers\compatibility.py:108, in EnvCompatibility.step(self, action)
#     105 obs, reward, done, info = self.env.step(action)
#     107 if self.render_mode == "human":
# --> 108     self.render()
#     110 return convert_to_terminated_truncated_step_api((obs, reward, done, info))
#
# File ~\.conda\envs\smbrl\lib\site-packages\gym\wrappers\compatibility.py:118, in EnvCompatibility.render(self)
#     112 def render(self) -> Any:
#     113     """Renders the environment.
#     114
#     115     Returns:
#     116         The rendering of the environment, depending on the render mode
#     117     """
# --> 118     return self.env.render(mode=self.render_mode)
#
# File ~\.conda\envs\smbrl\lib\site-packages\nes_py\nes_env.py:386, in NESEnv.render(self, mode)
#     380         self.viewer = ImageViewer(
#     381             caption=caption,
#     382             height=SCREEN_HEIGHT,
#     383             width=SCREEN_WIDTH,
#     384         )
#     385     # show the screen on the image viewer
# --> 386     self.viewer.show(self.screen)
#     387 elif mode == 'rgb_array':
#     388     return self.screen
#
# File ~\.conda\envs\smbrl\lib\site-packages\nes_py\_image_viewer.py:148, in ImageViewer.show(self, frame)
#     140 image = self.pyglet.image.ImageData(
#     141     frame.shape[1],
#     142     frame.shape[0],
#    (...)
#     145     pitch=frame.shape[1]*-3
#     146 )
#     147 # send the image to the window
# --> 148 image.blit(0, 0, width=self._window.width, height=self._window.height)
#     149 self._window.flip()
#
# File ~\.conda\envs\smbrl\lib\site-packages\pyglet\image\__init__.py:904, in ImageData.blit(self, x, y, z, width, height)
#     903 def blit(self, x, y, z=0, width=None, height=None):
# --> 904     self.get_texture().blit(x, y, z, width, height)
#
# File ~\.conda\envs\smbrl\lib\site-packages\pyglet\image\__init__.py:1619, in Texture.blit(self, x, y, z, width, height)
#    1617 glInterleavedArrays(GL_T4F_V4F, 0, array)
#    1618 glDrawArrays(GL_QUADS, 0, 4)
# -> 1619 glPopClientAttrib()
#    1620 glPopAttrib()
#
# File ~\.conda\envs\smbrl\lib\site-packages\pyglet\gl\lib.py:87, in errcheck(result, func, arguments)
#      83 class GLException(Exception):
#      84     pass
# ---> 87 def errcheck(result, func, arguments):
#      88     if _debug_gl_trace:
#      89         try:
#
# KeyboardInterrupt:

# %%
state = env.reset()

# %%
env.close()
